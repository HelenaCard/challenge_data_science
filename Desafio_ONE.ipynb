# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
loja['Receita Total'] = loja['Preço'] + loja['Frete']
loja2['Receita Total'] = loja2['Preço'] + loja2['Frete']
loja3['Receita Total'] = loja3['Preço'] + loja3['Frete']
loja4['Receita Total'] = loja4['Preço'] + loja4['Frete']

print("Total revenue for loja:", loja['Receita Total'].sum())
print("Total revenue for loja2:", loja2['Receita Total'].sum())
print("Total revenue for loja3:", loja3['Receita Total'].sum())
print("Total revenue for loja4:", loja4['Receita Total'].sum())
# Out:
# Total revenue for loja: 1616347.0877956916
# Total revenue for loja2: 1567773.218012645
# Total revenue for loja3: 1542047.691222643
# Total revenue for loja4: 1458253.455118983

# %% [markdown]
# # 2. Vendas por Categoria

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.bar(revenue_by_category['Categoria do Produto'], revenue_by_category['Receita Total'])
plt.title('Total Revenue by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
from matplotlib import pyplot as plt
_df_0['Avaliação da compra'].plot(kind='hist', bins=20, title='Avaliação da compra')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_14.groupby('Local da compra').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_10.groupby('Produto').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 7))
plt.bar(most_sold_products['Local da compra'], most_sold_products['Quantidade Vendida'])
plt.title('Most Sold Products by Store')
plt.xlabel('Store Location')
plt.ylabel('Quantity Sold')
plt.xticks(rotation=45, ha='right')
for i, row in most_sold_products.iterrows():
    plt.text(row['Local da compra'], row['Quantidade Vendida'], row['Produto'], ha='center', va='bottom', rotation=90)
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 7))
plt.bar(least_sold_products['Local da compra'], least_sold_products['Quantidade Vendida'], color='salmon')
plt.title('Least Sold Products by Store')
plt.xlabel('Store Location')
plt.ylabel('Quantity Sold')
plt.xticks(rotation=45, ha='right')
for i, row in least_sold_products.iterrows():
    plt.text(row['Local da compra'], row['Quantidade Vendida'], row['Produto'], ha='center', va='bottom', rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(x='Local da compra', y='Frete', data=average_frete_by_store.sort_values('Frete', ascending=False))
plt.xticks(rotation=90)
plt.title('Average Freight Cost by Store')
plt.xlabel('Store Location')
plt.ylabel('Average Freight Cost')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Análise de Faturamento Total das Lojas
#
# Nesta etapa, calculamos o faturamento total para cada uma das quatro lojas. O faturamento total foi obtido somando a 'Receita Total' (Preço + Frete) de todas as vendas em cada loja.
#
# **Resultados:**
#
# *   **Loja 1:** 1.616.347,09
# *   **Loja 2:** 1.567.773,22
# *   **Loja 3:** 1.542.047,69
# *   **Loja 4:** 1.458.253,46
#
# Com base no faturamento total, a **Loja 1** foi a que gerou maior receita.

# %% [markdown]
# ## Análise de Vendas por Categoria
#
# Aqui, analisamos a receita total gerada por cada categoria de produto. Agrupamos os dados pela 'Categoria do Produto' e somamos a 'Receita Total' para cada categoria.
#
# **Resultados:**
#
# O gráfico de barras acima mostra a receita total para cada categoria de produto. Observamos que as categorias **eletrônicos** e **eletrodomésticos** foram as que geraram maior receita, enquanto **livros** e **utilidades domésticas** tiveram o menor faturamento.

# %% [markdown]
# ## Análise da Média de Avaliação das Lojas
#
# Esta seção teve como objetivo entender a satisfação dos clientes calculando a média das avaliações para cada loja.
#
# **Observação:** O histograma apresentado na saída do código mostra a distribuição geral das avaliações, não a média por loja. Para visualizar a média por loja, o dataframe `average_rating_by_store` seria o mais indicado para plotagem.
#
# **Resultados (Baseado no dataframe `average_rating_by_store`):**
#
# Algumas lojas apresentaram médias de avaliação mais altas, como **RN**, **MT** e **SP**, indicando maior satisfação dos clientes nesses locais.

# %% [markdown]
# ## Análise de Produtos Mais e Menos Vendidos por Loja
#
# Nesta etapa, identificamos os produtos que tiveram o maior e o menor volume de vendas em cada loja.
#
# **Resultados:**
#
# Os gráficos de barras acima ilustram os produtos mais e menos vendidos em cada local de compra. Percebemos que os produtos de destaque e aqueles com menor saída variam significativamente entre as lojas, o que pode indicar diferenças no perfil dos consumidores ou na gestão de estoque de cada local. Por exemplo, em SP, o 'Carrinho controle remoto' foi o mais vendido, enquanto o 'Headset' foi o menos vendido.

# %% [markdown]
# ## Análise do Frete Médio por Loja
#
# Por fim, calculamos e visualizamos o custo médio do frete para cada loja.
#
# **Resultados:**
#
# O gráfico de barras acima mostra o custo médio do frete para cada local de compra, ordenado do maior para o menor. Identificamos que o frete médio varia consideravelmente entre as localidades, sendo **RR** o local com o frete médio mais alto e **AP** o local com o frete médio mais baixo. Isso pode ter implicações nos custos operacionais e na competitividade de preço em diferentes regiões.

# %% [markdown]
# ## Decisão de venda da Loja

# %% [markdown]
# Se a decisão for vender uma das lojas existentes, podemos considerar qual delas seria a "melhor" para vender com base no faturamento total. Geralmente, uma loja com maior faturamento tende a ter um valor de venda mais alto.
#
# Com base na análise de faturamento total que fizemos anteriormente:
#
# loja: 1616347.0877956916
# loja2: 1567773.218012645
# loja3: 1542047.691222643
# loja4: 1458253.455118983
# A loja com o maior faturamento total é a loja 1, com aproximadamente 1.6 milhão. Portanto, considerando apenas o faturamento total como métrica para determinar o valor de venda, a loja 1 seria a melhor opção para vender.
#
# É importante notar que outros fatores podem influenciar o valor de venda de uma loja, como a base de clientes, a reputação, os ativos físicos, contratos existentes e o potencial de crescimento futuro. No entanto, com base nos dados de faturamento fornecidos, a loja 1 é a que apresenta o desempenho financeiro mais forte em termos de receita total.
